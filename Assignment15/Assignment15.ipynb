# %% [markdown]
# # Assignment 15
# # Collin Dabbieri
#
# ### We ran a bunch of Cloudy runs with different metallicities and now we're going to look at line ratios of isoelectronic species for each metallicity
#
# $$\frac{NV}{CIV}$$<br>
# $$\frac{NV}{OVI}$$<br>
# $$\frac{NIV}{CIII}$$<br>
# $$\frac{NIV}{OV}$$<br>
# $$\frac{NV}{HeII}$$<br>
# $$\frac{CIV}{HeII}$$<br>
# $$\frac{OVI}{HeII}$$<br>

# %%
import numpy as np
from matplotlib import pyplot as plt
import sys
import os
import matplotlib

from pylab import rcParams
rcParams['figure.figsize'] = 15,8

# %% [markdown]
# # First for Z=0.2 solar
# ### The third line of these outputs is the line intensity

# %%
# !grep "He 2      1640.43A" kirk_0.2_line
# !grep "C  4      1550.78A" kirk_0.2_line
# !grep "C  4      1548.19A" kirk_0.2_line
# !grep "N  5      1238.82A" kirk_0.2_line
# !grep "N  5      1242.80A" kirk_0.2_line
# !grep "O  6      1037.62A" kirk_0.2_line
# !grep "O  6      1031.91A" kirk_0.2_line
# !grep "N  4      1486.50A" kirk_0.2_line
# !grep "N  4      1483.32A" kirk_0.2_line
# !grep "C  3      1908.73A" kirk_0.2_line
# !grep "C  3      1906.68A" kirk_0.2_line
# !grep "O  5      1218.34A" kirk_0.2_line
# !grep "O  5      1213.81A" kirk_0.2_line
# Out:
#  He 2      1640.43A	2.901e+05
#  C  4      1550.78A	1.139e+06
#  C  4      1548.19A	2.260e+06
#  N  5      1238.82A	7.345e+03
#  N  5      1242.80A	3.906e+03
#  O  6      1037.62A	3.820e+05
#  O  6      1031.91A	7.491e+05
#  N  4      1486.50A	7.487e+03
#  N  4      1483.32A	1.398e+00
#  C  3      1908.73A	1.106e+05
#  C  3      1906.68A	1.724e+01
#  O  5      1218.34A	2.734e+05
#  O  5      1213.81A	1.004e+02

# %%
He2_02=2.901e5
C4_02=1.139e6+2.260e6
N5_02=7.345e3+3.906e3
O6_02=3.820e5+7.491e5
N4_02=7.487e3+1.398e0
C3_02=1.106e5+1.724e1
O5_02=2.734e5+1.004e2

# %% [markdown]
# # Next for Z=0.5 solar

# %%
# !grep "He 2      1640.43A" kirk_0.5_line
# !grep "C  4      1550.78A" kirk_0.5_line
# !grep "C  4      1548.19A" kirk_0.5_line
# !grep "N  5      1238.82A" kirk_0.5_line
# !grep "N  5      1242.80A" kirk_0.5_line
# !grep "O  6      1037.62A" kirk_0.5_line
# !grep "O  6      1031.91A" kirk_0.5_line
# !grep "N  4      1486.50A" kirk_0.5_line
# !grep "N  4      1483.32A" kirk_0.5_line
# !grep "C  3      1908.73A" kirk_0.5_line
# !grep "C  3      1906.68A" kirk_0.5_line
# !grep "O  5      1218.34A" kirk_0.5_line
# !grep "O  5      1213.81A" kirk_0.5_line
# Out:
#  He 2      1640.43A	2.873e+05
#  C  4      1550.78A	1.358e+06
#  C  4      1548.19A	2.670e+06
#  N  5      1238.82A	5.253e+04
#  N  5      1242.80A	2.686e+04
#  O  6      1037.62A	4.075e+05
#  O  6      1031.91A	7.945e+05
#  N  4      1486.50A	5.585e+04
#  N  4      1483.32A	9.609e+00
#  C  3      1908.73A	1.802e+05
#  C  3      1906.68A	2.777e+01
#  O  5      1218.34A	3.266e+05
#  O  5      1213.81A	1.085e+02

# %%
He2_05=2.873e5
C4_05=1.358e6+2.670e6
N5_05=5.253e4+2.686e4
O6_05=4.075e5+7.945e5
N4_05=5.585e4+9.609e0
C3_05=1.802e5+2.777e1
O5_05=3.266e5+1.085e2

# %% [markdown]
# # Z=1.0 solar

# %%
# !grep "He 2      1640.43A" kirk_1_line
# !grep "C  4      1550.78A" kirk_1_line
# !grep "C  4      1548.19A" kirk_1_line
# !grep "N  5      1238.82A" kirk_1_line
# !grep "N  5      1242.80A" kirk_1_line
# !grep "O  6      1037.62A" kirk_1_line
# !grep "O  6      1031.91A" kirk_1_line
# !grep "N  4      1486.50A" kirk_1_line
# !grep "N  4      1483.32A" kirk_1_line
# !grep "C  3      1908.73A" kirk_1_line
# !grep "C  3      1906.68A" kirk_1_line
# !grep "O  5      1218.34A" kirk_1_line
# !grep "O  5      1213.81A" kirk_1_line
# Out:
#  He 2      1640.43A	2.792e+05
#  C  4      1550.78A	1.323e+06
#  C  4      1548.19A	2.566e+06
#  N  5      1238.82A	2.152e+05
#  N  5      1242.80A	1.095e+05
#  O  6      1037.62A	3.549e+05
#  O  6      1031.91A	6.880e+05
#  N  4      1486.50A	2.212e+05
#  N  4      1483.32A	3.648e+01
#  C  3      1908.73A	2.918e+05
#  C  3      1906.68A	4.519e+01
#  O  5      1218.34A	3.520e+05
#  O  5      1213.81A	1.095e+02

# %%
He2_1=2.792e5
C4_1=1.323e6+2.566e6
N5_1=2.152e5+1.095e5
O6_1=3.549e5+6.880e5
N4_1=2.212e5+3.648e1
C3_1=2.918e5+4.519e1
O5_1=3.520e5+1.095e2

# %% [markdown]
# # Z=2.0 solar

# %%
# !grep "He 2      1640.43A" kirk_2_line
# !grep "C  4      1550.78A" kirk_2_line
# !grep "C  4      1548.19A" kirk_2_line
# !grep "N  5      1238.82A" kirk_2_line
# !grep "N  5      1242.80A" kirk_2_line
# !grep "O  6      1037.62A" kirk_2_line
# !grep "O  6      1031.91A" kirk_2_line
# !grep "N  4      1486.50A" kirk_2_line
# !grep "N  4      1483.32A" kirk_2_line
# !grep "C  3      1908.73A" kirk_2_line
# !grep "C  3      1906.68A" kirk_2_line
# !grep "O  5      1218.34A" kirk_2_line
# !grep "O  5      1213.81A" kirk_2_line
# Out:
#  He 2      1640.43A	2.583e+05
#  C  4      1550.78A	6.714e+05
#  C  4      1548.19A	1.300e+06
#  N  5      1238.82A	6.729e+05
#  N  5      1242.80A	3.444e+05
#  O  6      1037.62A	1.989e+05
#  O  6      1031.91A	3.825e+05
#  N  4      1486.50A	4.703e+05
#  N  4      1483.32A	7.856e+01
#  C  3      1908.73A	9.896e+05
#  C  3      1906.68A	1.702e+02
#  O  5      1218.34A	2.841e+05
#  O  5      1213.81A	8.367e+01

# %%
He2_2=2.583e5
C4_2=6.714e5+1.300e6
N5_2=6.729e5+3.444e5
O6_2=1.989e5+3.825e5
N4_2=4.703e5+7.856e1
C3_2=9.896e5+1.702e2
O5_2=2.841e5+8.367e1

# %% [markdown]
# # Z=5.0 solar

# %%
# !grep "He 2      1640.43A" kirk_5_line
# !grep "C  4      1550.78A" kirk_5_line
# !grep "C  4      1548.19A" kirk_5_line
# !grep "N  5      1238.82A" kirk_5_line
# !grep "N  5      1242.80A" kirk_5_line
# !grep "O  6      1037.62A" kirk_5_line
# !grep "O  6      1031.91A" kirk_5_line
# !grep "N  4      1486.50A" kirk_5_line
# !grep "N  4      1483.32A" kirk_5_line
# !grep "C  3      1908.73A" kirk_5_line
# !grep "C  3      1906.68A" kirk_5_line
# !grep "O  5      1218.34A" kirk_5_line
# !grep "O  5      1213.81A" kirk_5_line
# Out:
#  He 2      1640.43A	1.549e+05
#  C  4      1550.78A	1.165e+05
#  C  4      1548.19A	2.284e+05
#  N  5      1238.82A	9.970e+05
#  N  5      1242.80A	5.244e+05
#  O  6      1037.62A	2.954e+04
#  O  6      1031.91A	5.584e+04
#  N  4      1486.50A	9.530e+05
#  N  4      1483.32A	1.677e+02
#  C  3      1908.73A	8.067e+05
#  C  3      1906.68A	1.820e+02
#  O  5      1218.34A	6.030e+04
#  O  5      1213.81A	1.527e+01

# %%
He2_5=1.549e5
C4_5=1.165e5+2.284e5
N5_5=9.970e5+5.244e5
O6_5=2.954e4+5.584e4
N4_5=9.530e5+1.677e2
C3_5=8.067e5+1.820e2
O5_5=6.030e4+1.527e1

# %% [markdown]
# # Z = 10.0 solar

# %%
# !grep "He 2      1640.43A" kirk_10_line
# !grep "C  4      1550.78A" kirk_10_line
# !grep "C  4      1548.19A" kirk_10_line
# !grep "N  5      1238.82A" kirk_10_line
# !grep "N  5      1242.80A" kirk_10_line
# !grep "O  6      1037.62A" kirk_10_line
# !grep "O  6      1031.91A" kirk_10_line
# !grep "N  4      1486.50A" kirk_10_line
# !grep "N  4      1483.32A" kirk_10_line
# !grep "C  3      1908.73A" kirk_10_line
# !grep "C  3      1906.68A" kirk_10_line
# !grep "O  5      1218.34A" kirk_10_line
# !grep "O  5      1213.81A" kirk_10_line
# Out:
#  He 2      1640.43A	4.771e+04
#  C  4      1550.78A	4.239e+04
#  C  4      1548.19A	8.303e+04
#  N  5      1238.82A	8.828e+05
#  N  5      1242.80A	4.738e+05
#  O  6      1037.62A	4.954e+03
#  O  6      1031.91A	8.975e+03
#  N  4      1486.50A	1.559e+06
#  N  4      1483.32A	2.906e+02
#  C  3      1908.73A	2.817e+05
#  C  3      1906.68A	5.802e+01
#  O  5      1218.34A	1.320e+04
#  O  5      1213.81A	2.510e+00

# %%
He2_10=4.771e4
C4_10=4.239e4+8.303e4
N5_10=8.828e5+4.738e5
O6_10=4.954e3+8.975e3
N4_10=1.559e6+2.906e2
C3_10=2.817e5+5.802e1
O5_10=1.320e4+2.510e0

# %%
matplotlib.rcParams['text.usetex'] = True
vector_02=[N5_02/C4_02,N5_02/O6_02,N4_02/C3_02,N4_02/O5_02,N5_02/He2_02,C4_02/He2_02,O6_02/He2_02]
vector_05=[N5_05/C4_05,N5_05/O6_05,N4_05/C3_05,N4_05/O5_05,N5_05/He2_05,C4_05/He2_05,O6_05/He2_05]
vector_1=[N5_1/C4_1,N5_1/O6_1,N4_1/C3_1,N4_1/O5_1,N5_1/He2_1,C4_1/He2_1,O6_1/He2_1]
vector_2=[N5_2/C4_2,N5_2/O6_2,N4_2/C3_2,N4_2/O5_2,N5_2/He2_2,C4_2/He2_2,O6_2/He2_2]
vector_5=[N5_5/C4_5,N5_5/O6_5,N4_5/C3_5,N4_5/O5_5,N5_5/He2_5,C4_5/He2_5,O6_5/He2_5]
vector_10=[N5_10/C4_10,N5_10/O6_10,N4_10/C3_10,N4_10/O5_10,N5_10/He2_10,C4_10/He2_10,O6_10/He2_10]

x=np.arange(7)
cmap = matplotlib.cm.get_cmap('viridis')

plt.scatter(x,vector_02,c=cmap(1/7),label="Z=0.2",s=80)
plt.scatter(x,vector_05,c=cmap(2/7),label="Z=0.5",s=80)
plt.scatter(x,vector_1,c=cmap(3/7),label="Z=1.0",s=80)
plt.scatter(x,vector_2,c=cmap(4/7),label="Z=2.0",s=80)
plt.scatter(x,vector_5,c=cmap(5/7),label="Z=5.0",s=80)
plt.scatter(x,vector_10,c=cmap(6/7),label="Z=10.0",s=80)
plt.legend(fontsize=18)
plt.yscale("log")
plt.ylabel("Intensity",fontsize=24)

plt.xticks(np.arange(7),\
           labels=(r"$\frac{NV}{CIV}$",r"$\frac{NV}{OVI}$",r"$\frac{NIV}{CIII}$",\
                   r"$\frac{NIV}{OV}$",r"$\frac{NV}{HeII}$",r"$\frac{CIV}{HeII}$",r"$\frac{OVI}{HeII}$"),fontsize=24)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# # We could also plot individual line ratios as a function of metallicity

# %%
Z=[0.2,0.5,1.0,2.0,5.0,10.0]

N5C4=[N5_02/C4_02,N5_05/C4_05,N5_1/C4_1,N5_2/C4_2,N5_5/C4_5,N5_10/C4_10]

plt.loglog(Z,N5C4)
plt.xlabel("Metallicity",fontsize=24)
plt.ylabel(r"$\frac{NV}{CIV}$",fontsize=24)
# Out:
# Text(0, 0.5, '$\\frac{NV}{CIV}$')

# %%
Z=[0.2,0.5,1.0,2.0,5.0,10.0]

N5O6=[N5_02/O6_02,N5_05/O6_05,N5_1/O6_1,N5_2/O6_2,N5_5/O6_5,N5_10/O6_10]

plt.loglog(Z,N5O6)
plt.xlabel("Metallicity",fontsize=24)
plt.ylabel(r"$\frac{NV}{OVI}$",fontsize=24)
# Out:
# Text(0, 0.5, '$\\frac{NV}{OVI}$')

# %%
Z=[0.2,0.5,1.0,2.0,5.0,10.0]

N4C3=[N4_02/C3_02,N4_05/C3_05,N4_1/C3_1,N4_2/C3_2,N4_5/C3_5,N4_10/C3_10]

plt.loglog(Z,N4C3)
plt.xlabel("Metallicity",fontsize=24)
plt.ylabel(r"$\frac{NIV}{CIII}$",fontsize=24)
# Out:
# Text(0, 0.5, '$\\frac{NIV}{CIII}$')

# %%
Z=[0.2,0.5,1.0,2.0,5.0,10.0]

N4O5=[N4_02/O5_02,N4_05/O5_05,N4_1/O5_1,N4_2/O5_2,N4_5/O5_5,N4_10/O5_10]

plt.loglog(Z,N4O5)
plt.xlabel("Metallicity",fontsize=24)
plt.ylabel(r"$\frac{NIV}{OV}$",fontsize=24)
# Out:
# Text(0, 0.5, '$\\frac{NIV}{OV}$')

# %%
Z=[0.2,0.5,1.0,2.0,5.0,10.0]

N5He2=[N5_02/He2_02,N5_05/He2_05,N5_1/He2_1,N5_2/He2_2,N5_5/He2_5,N5_10/He2_10]

plt.loglog(Z,N5He2)
plt.xlabel("Metallicity",fontsize=24)
plt.ylabel(r"$\frac{NV}{HeII}$",fontsize=24)
# Out:
# Text(0, 0.5, '$\\frac{NV}{HeII}$')

# %%
Z=[0.2,0.5,1.0,2.0,5.0,10.0]

C4He2=[C4_02/He2_02,C4_05/He2_05,C4_1/He2_1,C4_2/He2_2,C4_5/He2_5,C4_10/He2_10]

plt.loglog(Z,C4He2)
plt.xlabel("Metallicity",fontsize=24)
plt.ylabel(r"$\frac{CIV}{HeII}$",fontsize=24)
# Out:
# Text(0, 0.5, '$\\frac{CIV}{HeII}$')

# %%
Z=[0.2,0.5,1.0,2.0,5.0,10.0]

O6He2=[O6_02/He2_02,O6_05/He2_05,O6_1/He2_1,O6_2/He2_2,O6_5/He2_5,O6_10/He2_10]

plt.loglog(Z,O6He2)
plt.xlabel("Metallicity",fontsize=24)
plt.ylabel(r"$\frac{OVI}{HeII}$",fontsize=24)
# Out:
# Text(0, 0.5, '$\\frac{OVI}{HeII}$')

# %% [markdown]
# Because Nitrogen abundance increases as $Z^2$ with increasing metallicity, we see increasing ratios of Nitrogen over other atoms with increasing metallicity. Because Helium abundance increases more slowly than other metals with increasing metallicity, we see decreasing ratios of Helium over other atoms with increasing metallicity.
